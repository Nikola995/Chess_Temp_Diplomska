# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Libraries" data-toc-modified-id="Libraries-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Libraries</a></span><ul class="toc-item"><li><span><a href="#Helper-functions" data-toc-modified-id="Helper-functions-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Helper functions</a></span></li></ul></li><li><span><a href="#First-model/user-analysis" data-toc-modified-id="First-model/user-analysis-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>First model/user analysis</a></span><ul class="toc-item"><li><span><a href="#Training-loss-only-on-last-state-prediction" data-toc-modified-id="Training-loss-only-on-last-state-prediction-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Training loss only on last state prediction</a></span><ul class="toc-item"><li><span><a href="#Accuracy-(total)-only-on-last-state-prediction" data-toc-modified-id="Accuracy-(total)-only-on-last-state-prediction-2.1.1"><span class="toc-item-num">2.1.1&nbsp;&nbsp;</span>Accuracy (total) only on last state prediction</a></span><ul class="toc-item"><li><span><a href="#Accuracy-(total)-plot-only-on-last-state-prediction" data-toc-modified-id="Accuracy-(total)-plot-only-on-last-state-prediction-2.1.1.1"><span class="toc-item-num">2.1.1.1&nbsp;&nbsp;</span>Accuracy (total) plot only on last state prediction</a></span></li></ul></li><li><span><a href="#Accuracy-by-turn-only-on-last-state-prediction" data-toc-modified-id="Accuracy-by-turn-only-on-last-state-prediction-2.1.2"><span class="toc-item-num">2.1.2&nbsp;&nbsp;</span>Accuracy by turn only on last state prediction</a></span><ul class="toc-item"><li><span><a href="#Accuracy-by-turn-plot-only-on-last-state-prediction" data-toc-modified-id="Accuracy-by-turn-plot-only-on-last-state-prediction-2.1.2.1"><span class="toc-item-num">2.1.2.1&nbsp;&nbsp;</span>Accuracy by turn plot only on last state prediction</a></span></li></ul></li><li><span><a href="#Train-loss-only-on-last-state-prediction" data-toc-modified-id="Train-loss-only-on-last-state-prediction-2.1.3"><span class="toc-item-num">2.1.3&nbsp;&nbsp;</span>Train loss only on last state prediction</a></span></li></ul></li><li><span><a href="#Training-loss-on-all-state-predictions-(linear)" data-toc-modified-id="Training-loss-on-all-state-predictions-(linear)-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Training loss on all state predictions (linear)</a></span><ul class="toc-item"><li><span><a href="#Accuracy-(total)" data-toc-modified-id="Accuracy-(total)-2.2.1"><span class="toc-item-num">2.2.1&nbsp;&nbsp;</span>Accuracy (total)</a></span><ul class="toc-item"><li><span><a href="#Accuracy-(total)-on-all-state-predictions-(linear)" data-toc-modified-id="Accuracy-(total)-on-all-state-predictions-(linear)-2.2.1.1"><span class="toc-item-num">2.2.1.1&nbsp;&nbsp;</span>Accuracy (total) on all state predictions (linear)</a></span></li></ul></li><li><span><a href="#Accuracy-by-turn-on-all-state-predictions-(linear)" data-toc-modified-id="Accuracy-by-turn-on-all-state-predictions-(linear)-2.2.2"><span class="toc-item-num">2.2.2&nbsp;&nbsp;</span>Accuracy by turn on all state predictions (linear)</a></span><ul class="toc-item"><li><span><a href="#Accuracy-by-turn-plot-on-all-state-predictions-(linear)" data-toc-modified-id="Accuracy-by-turn-plot-on-all-state-predictions-(linear)-2.2.2.1"><span class="toc-item-num">2.2.2.1&nbsp;&nbsp;</span>Accuracy by turn plot on all state predictions (linear)</a></span></li></ul></li><li><span><a href="#Train-loss-on-all-state-predictions-(linear)" data-toc-modified-id="Train-loss-on-all-state-predictions-(linear)-2.2.3"><span class="toc-item-num">2.2.3&nbsp;&nbsp;</span>Train loss on all state predictions (linear)</a></span></li></ul></li><li><span><a href="#Training-loss-on-all-state-predictions-(convolutional)" data-toc-modified-id="Training-loss-on-all-state-predictions-(convolutional)-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Training loss on all state predictions (convolutional)</a></span><ul class="toc-item"><li><span><a href="#Accuracy-(total)-on-all-state-predictions-(convolutional)" data-toc-modified-id="Accuracy-(total)-on-all-state-predictions-(convolutional)-2.3.1"><span class="toc-item-num">2.3.1&nbsp;&nbsp;</span>Accuracy (total) on all state predictions (convolutional)</a></span><ul class="toc-item"><li><span><a href="#Accuracy-(total)-on-all-state-predictions-(convolutional)" data-toc-modified-id="Accuracy-(total)-on-all-state-predictions-(convolutional)-2.3.1.1"><span class="toc-item-num">2.3.1.1&nbsp;&nbsp;</span>Accuracy (total) on all state predictions (convolutional)</a></span></li></ul></li><li><span><a href="#Accuracy-by-turn-on-all-state-predictions-(convolutional)" data-toc-modified-id="Accuracy-by-turn-on-all-state-predictions-(convolutional)-2.3.2"><span class="toc-item-num">2.3.2&nbsp;&nbsp;</span>Accuracy by turn on all state predictions (convolutional)</a></span><ul class="toc-item"><li><span><a href="#Accuracy-by-turn-plot-on-all-state-predictions-(convolutional)" data-toc-modified-id="Accuracy-by-turn-plot-on-all-state-predictions-(convolutional)-2.3.2.1"><span class="toc-item-num">2.3.2.1&nbsp;&nbsp;</span>Accuracy by turn plot on all state predictions (convolutional)</a></span></li></ul></li><li><span><a href="#Train-loss-on-all-state-predictions-(convolutional)" data-toc-modified-id="Train-loss-on-all-state-predictions-(convolutional)-2.3.3"><span class="toc-item-num">2.3.3&nbsp;&nbsp;</span>Train loss on all state predictions (convolutional)</a></span></li></ul></li></ul></li></ul></div>

# %% [markdown]
# # Libraries

# %%
#OS libs
import os
import sys
from pathlib import Path
from io import StringIO
#Data handling libs
import pandas as pd
from tqdm import tqdm
from chess.pgn import read_game, BaseVisitor
import chess.engine
#Data visualization libraries
import matplotlib.pyplot as plt
from matplotlib.colors import LogNorm
from matplotlib import dates as mdates
from matplotlib.dates import DateFormatter
from matplotlib.ticker import MultipleLocator, FuncFormatter, LogLocator
from mpl_toolkits.mplot3d import Axes3D
import seaborn as sns
import matplotlib.patches as mplp

# %% [markdown]
# ## Helper functions

# %%
def filter_by(files, num_users = 0, user = 0):
    if num_users:
        filtered_files = [x for x in files if int(x.split('_')[1]) == num_users]
        # Sort ascending
        filtered_files.sort(key=lambda x: int(x.split('_')[2]),
                                  reverse=True)
        return filtered_files
    elif user:
        filtered_files = [x for x  in files if int(x.split('_')[2]) == user]
        # Sort ascending
        filtered_files.sort(key=lambda x: int(x.split('_')[1]))
        return filtered_files
    else:
        raise ValueError()
#first_user = filter_by(predictions, user=400)

def round_down(x, base=5):
    return x - (x % base)

def round_up(x, base=5):
    result = x + ((base - x) % base)
    # In this perticular case hard cap to 100
    # because we are working with accuracy
    if result > 100:
       result = 100
    return result

# print(round_down(df.describe()['min'],5))
# print(round_up(df.describe()['max'],5))

# %%
def unique_predictions(pred_folder, pred_file):
    pred_df = pd.read_csv(os.path.join(pred_folder,
                                       pred_file),
                          index_col=None)
    # %% Train data
    train_datasets = os.listdir(os.path.join(os.getcwd(),
                                             'dt_chess',
                                             'datasets'))
    train_data = [x for x in train_datasets if x.partition('_')[0] == pred_file.split('_')[2]][0]
    train_df = pd.read_csv(os.path.join(os.getcwd(),
                                        'dt_chess',
                                        'datasets',
                                        train_data),
                           index_col=(0))
    train_df.rename(columns={'positions': 'board', 'moves': 'move'}, inplace=True)
    train_df.drop_duplicates(inplace=True)
    # Remove duplicates from train data
    pred_df_fin = pd.merge(pred_df, train_df,
                           on=["board","move"], how='left',
                           indicator='Exist')
    #common_total = len(pred_df_fin[pred_df_fin['Exist'] == 'both'])
    pred_df_fin = pred_df_fin[pred_df_fin['Exist'] == 'left_only']
    return pred_df_fin

def get_stats_for_predictions(pred_all_1_df):
    total = len(pred_all_1_df)
    fp = len(pred_all_1_df[pred_all_1_df['illegal_top_move']])
    tp1 = len(pred_all_1_df[pred_all_1_df['move'] == pred_all_1_df['engine_move_1']])
    tp2 = len(pred_all_1_df[pred_all_1_df['move'] == pred_all_1_df['engine_move_2']])
    tp3 = len(pred_all_1_df[pred_all_1_df['move'] == pred_all_1_df['engine_move_3']])
    tn1 = total - tp1
    tn2 = total - (tp1 + tp2)
    tn3 = total - (tp1 + tp2 + tp3)
    acc1 = (tp1/total)*100
    acc2 = (tp2/total)*100
    acc3 = (tp3/total)*100
    acctop2 = ((tp1 + tp2)/total)*100
    acctop3 = ((tp1 + tp2 + tp3)/total)*100
    return (total, fp, tp1, tp2, tp3, tn1, tn2, tn3, acc1, acc2, acc3, acctop2, acctop3)

def get_stats_for_all_predictions(pred_folder, user_predictions,
                                  unique=True, verbose=True):
    stats = []
    pred_list = tqdm(user_predictions) if verbose else user_predictions
    for user_pred_file in pred_list:
        if unique:
            pred_df = unique_predictions(pred_folder, user_pred_file)
        else:
            pred_df = pd.read_csv(os.path.join(pred_folder,
                                               user_pred_file),
                                  index_col=None)
        stats.append(get_stats_for_predictions(pred_df))
    return pd.DataFrame(stats, columns =["total", "fp",
                                         "tp1", "tp2", "tp3",
                                         "tn1", "tn2", "tn3",
                                         "acc1", "acc2", "acc3", "acctop2", "acctop3"])

def get_stats_for_predictions_by_turn(pred_folder, user_predictions, verbose = True):
    stats_by_turn_all_files = {}
    pred_list = tqdm(user_predictions) if verbose else user_predictions
    for user_pred_file in pred_list:
        pred_df = unique_predictions(pred_folder, user_pred_file)
        pred_by_turn = pred_df.groupby(['turn'])
        pred_single_turn_dfs = [pred_by_turn.get_group(x) for x in pred_by_turn.groups]
        pred_turn_stats = [get_stats_for_predictions(x) for x in pred_single_turn_dfs]
        pred_turn_stats_df = pd.DataFrame(pred_turn_stats, columns =["total", "fp",
                                         "tp1", "tp2", "tp3",
                                         "tn1", "tn2", "tn3",
                                         "acc1", "acc2", "acc3", "acctop2", "acctop3"])
        pred_turn_stats_df.index = pred_by_turn.groups.keys()
        stats_by_turn_all_files[user_pred_file[:-len('.csv')]] = pred_turn_stats_df
    return stats_by_turn_all_files

def get_train_losses(losses_dir, loss_files):
    losses_df = []
    for loss_file in loss_files:
        loss_df = pd.read_csv(os.path.join(losses_dir, loss_file),
                              header=0)
        loss_epoch = loss_file.rpartition('_')[-1][:-len('.csv')]
        loss_df.rename(columns={loss_df.columns[0]: f"epoch_{loss_epoch}"},
                      inplace=True)
        losses_df.append(loss_df)
    return pd.concat(losses_df,axis=1)

# %%
### All predictions plot ##
def plot_accuracy_by_epoch(accuracy_df, loss_type, state_emb_type):
    #PDF plot
    plt.figure(figsize=(16, 10))
    ax = sns.lineplot(data = accuracy_df)
    ax.set(xlabel='Epoch')
    ax.set(ylabel='Accuracy')
    #Set major and minor ticks
    ax.yaxis.set_major_locator(MultipleLocator(5))
    ax.yaxis.set_minor_locator(MultipleLocator(1))
    ax.tick_params(axis='y', which='both', left=True)
    ax.xaxis.set_major_locator(MultipleLocator(1))
    #ax.xaxis.set_minor_locator(MultipleLocator(1))
    ax.tick_params(axis='x', which='both', bottom=True)
    ax.tick_params(axis="x", which="both", rotation=45)
    #Extend y-limits
    #Get the min of all accuracy values
    plt.ylim(round_down(accuracy_df.min().min(),5),
             round_up(accuracy_df.max().max(),5))
    #Tighted x-limits
    plt.xlim(accuracy_df.index.min(),
             accuracy_df.index.max())
    #Set grid
    plt.grid(visible = True, which = 'both', axis = 'y', linestyle = '-',zorder=0)
    plt.grid(visible = True, which = 'both', axis = 'x', linestyle = '-',zorder=0)
    plt.title(f"All predictions accuracies by epoch (Training loss - {loss_type}) "
              f"({state_emb_type} model)")
    plt.tight_layout()
    plt.show()

def plot_acc_by_turn(accuracy_df, epoch, loss_type, state_emb_type):
    #PDF plot
    plt.figure(figsize=(16, 10))
    ax = sns.lineplot(data = accuracy_df)
    ax.set(xlabel='Turn')
    ax.set(ylabel='Accuracy')
    #Set major and minor ticks
    ax.yaxis.set_major_locator(MultipleLocator(5))
    ax.yaxis.set_minor_locator(MultipleLocator(1))
    ax.tick_params(axis='y', which='both', left=True)
    ax.xaxis.set_major_locator(MultipleLocator(5))
    ax.xaxis.set_minor_locator(MultipleLocator(1))
    ax.tick_params(axis='x', which='both', bottom=True)
    ax.tick_params(axis="x", which="both", rotation=45)
    #Extend y-limits
    #Get the min of all accuracy values
    global_min = accuracy_df.describe().loc['min'].min()
    global_max = accuracy_df.describe().loc['max'].max()
    plt.ylim(round_down(global_min,5),
             round_up(global_max,5))
    #Tighted x-limits
    plt.xlim(accuracy_df.index.min(),
             accuracy_df.index.max())
    #Set grid
    plt.grid(visible = True, which = 'both', axis = 'y', linestyle = '-',zorder=0)
    plt.grid(visible = True, which = 'both', axis = 'x', linestyle = '-',zorder=0)
    plt.title(f"All predictions accuracy by turn ({epoch}) "
              f"(Training loss - {loss_type}) ({state_emb_type} model)")
    plt.tight_layout()
    plt.show()
    
def plot_train_loss(losses_df, epoch, loss_type, state_emb_type):
    #PDF plot
    plt.figure(figsize=(16, 10))
    ax = sns.lineplot(data = losses_df, alpha  = 0.7)
    ax.set(xlabel='Iteration')
    ax.set(ylabel='Train Loss')
    #Set major and minor ticks
    ax.yaxis.set_major_locator(MultipleLocator(0.5))
    ax.yaxis.set_minor_locator(MultipleLocator(0.1))
    ax.tick_params(axis='y', which='both', left=True)
    ax.xaxis.set_major_locator(MultipleLocator(50))
    ax.xaxis.set_minor_locator(MultipleLocator(10))
    ax.tick_params(axis='x', which='both', bottom=True)
    ax.tick_params(axis="x", which="both", rotation=45)
    #Extend y-limits
    plt.ylim(round_down(losses_df.min().min(),0.5),
             round_up(losses_df.max().max(),0.5))
    #Tighted x-limits
    plt.xlim(0,len(losses_df)-1)
    #Set grid
    plt.grid(visible = True, which = 'major', axis = 'y', linestyle = '-',zorder=0)
    plt.grid(visible = True, which = 'major', axis = 'x', linestyle = '-',zorder=0)
    plt.title(f"First model's train loss for {epoch} (batch size = 256)"
              f" (Training loss - {loss_type}) ({state_emb_type} model)")
    plt.tight_layout()
    plt.show()

# %% [markdown]
# # First model/user analysis

# %% [markdown]
# ## Training loss only on last state prediction

# %%
#Meta-data
dt_pred_folder_old = os.path.join(os.getcwd(),'dt_chess','datasets_test_predictions_1_last')
state_emb_type = 'linear'
predictions_old = os.listdir(dt_pred_folder_old)
predictions_old = [x for x in predictions_old if x.partition('_')[0] == state_emb_type]
predictions_old
# Out:
# ['linear_1_400_Jiyarkhan_1.csv',
#  'linear_1_400_Jiyarkhan_2.csv',
#  'linear_1_400_Jiyarkhan_3.csv',
#  'linear_1_400_Jiyarkhan_4.csv',
#  'linear_1_400_Jiyarkhan_5.csv']

# %% [markdown]
# ### Accuracy (total) only on last state prediction

# %%
mu_1_df = get_stats_for_all_predictions(dt_pred_folder_old, predictions_old, unique=True)
mu_1_df.index += 1 
display(mu_1_df.style.format(thousands=','))
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████████| 5/5 [00:16<00:00,  3.28s/it]
# <style type="text/css">
# </style>
# <table id="T_f9233">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f9233_level0_col0" class="col_heading level0 col0" >total</th>
#       <th id="T_f9233_level0_col1" class="col_heading level0 col1" >fp</th>
#       <th id="T_f9233_level0_col2" class="col_heading level0 col2" >tp1</th>
#       <th id="T_f9233_level0_col3" class="col_heading level0 col3" >tp2</th>
#       <th id="T_f9233_level0_col4" class="col_heading level0 col4" >tp3</th>
#       <th id="T_f9233_level0_col5" class="col_heading level0 col5" >tn1</th>
#       <th id="T_f9233_level0_col6" class="col_heading level0 col6" >tn2</th>
#       <th id="T_f9233_level0_col7" class="col_heading level0 col7" >tn3</th>
#       <th id="T_f9233_level0_col8" class="col_heading level0 col8" >acc1</th>
#       <th id="T_f9233_level0_col9" class="col_heading level0 col9" >acc2</th>
#       <th id="T_f9233_level0_col10" class="col_heading level0 col10" >acc3</th>
#       <th id="T_f9233_level0_col11" class="col_heading level0 col11" >acctop2</th>
#       <th id="T_f9233_level0_col12" class="col_heading level0 col12" >acctop3</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f9233_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_f9233_row0_col0" class="data row0 col0" >124,632</td>
#       <td id="T_f9233_row0_col1" class="data row0 col1" >62,379</td>
#       <td id="T_f9233_row0_col2" class="data row0 col2" >19,212</td>
#       <td id="T_f9233_row0_col3" class="data row0 col3" >11,594</td>
#       <td id="T_f9233_row0_col4" class="data row0 col4" >8,372</td>
#       <td id="T_f9233_row0_col5" class="data row0 col5" >105,420</td>
#       <td id="T_f9233_row0_col6" class="data row0 col6" >93,826</td>
#       <td id="T_f9233_row0_col7" class="data row0 col7" >85,454</td>
#       <td id="T_f9233_row0_col8" class="data row0 col8" >15.414982</td>
#       <td id="T_f9233_row0_col9" class="data row0 col9" >9.302587</td>
#       <td id="T_f9233_row0_col10" class="data row0 col10" >6.717376</td>
#       <td id="T_f9233_row0_col11" class="data row0 col11" >24.717569</td>
#       <td id="T_f9233_row0_col12" class="data row0 col12" >31.434944</td>
#     </tr>
#     <tr>
#       <th id="T_f9233_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_f9233_row1_col0" class="data row1 col0" >124,632</td>
#       <td id="T_f9233_row1_col1" class="data row1 col1" >48,978</td>
#       <td id="T_f9233_row1_col2" class="data row1 col2" >21,562</td>
#       <td id="T_f9233_row1_col3" class="data row1 col3" >12,172</td>
#       <td id="T_f9233_row1_col4" class="data row1 col4" >8,702</td>
#       <td id="T_f9233_row1_col5" class="data row1 col5" >103,070</td>
#       <td id="T_f9233_row1_col6" class="data row1 col6" >90,898</td>
#       <td id="T_f9233_row1_col7" class="data row1 col7" >82,196</td>
#       <td id="T_f9233_row1_col8" class="data row1 col8" >17.300533</td>
#       <td id="T_f9233_row1_col9" class="data row1 col9" >9.766352</td>
#       <td id="T_f9233_row1_col10" class="data row1 col10" >6.982155</td>
#       <td id="T_f9233_row1_col11" class="data row1 col11" >27.066885</td>
#       <td id="T_f9233_row1_col12" class="data row1 col12" >34.049040</td>
#     </tr>
#     <tr>
#       <th id="T_f9233_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_f9233_row2_col0" class="data row2 col0" >124,633</td>
#       <td id="T_f9233_row2_col1" class="data row2 col1" >41,845</td>
#       <td id="T_f9233_row2_col2" class="data row2 col2" >23,362</td>
#       <td id="T_f9233_row2_col3" class="data row2 col3" >12,909</td>
#       <td id="T_f9233_row2_col4" class="data row2 col4" >9,223</td>
#       <td id="T_f9233_row2_col5" class="data row2 col5" >101,271</td>
#       <td id="T_f9233_row2_col6" class="data row2 col6" >88,362</td>
#       <td id="T_f9233_row2_col7" class="data row2 col7" >79,139</td>
#       <td id="T_f9233_row2_col8" class="data row2 col8" >18.744634</td>
#       <td id="T_f9233_row2_col9" class="data row2 col9" >10.357610</td>
#       <td id="T_f9233_row2_col10" class="data row2 col10" >7.400127</td>
#       <td id="T_f9233_row2_col11" class="data row2 col11" >29.102244</td>
#       <td id="T_f9233_row2_col12" class="data row2 col12" >36.502371</td>
#     </tr>
#     <tr>
#       <th id="T_f9233_level0_row3" class="row_heading level0 row3" >4</th>
#       <td id="T_f9233_row3_col0" class="data row3 col0" >124,637</td>
#       <td id="T_f9233_row3_col1" class="data row3 col1" >40,205</td>
#       <td id="T_f9233_row3_col2" class="data row3 col2" >24,013</td>
#       <td id="T_f9233_row3_col3" class="data row3 col3" >13,304</td>
#       <td id="T_f9233_row3_col4" class="data row3 col4" >9,019</td>
#       <td id="T_f9233_row3_col5" class="data row3 col5" >100,624</td>
#       <td id="T_f9233_row3_col6" class="data row3 col6" >87,320</td>
#       <td id="T_f9233_row3_col7" class="data row3 col7" >78,301</td>
#       <td id="T_f9233_row3_col8" class="data row3 col8" >19.266349</td>
#       <td id="T_f9233_row3_col9" class="data row3 col9" >10.674198</td>
#       <td id="T_f9233_row3_col10" class="data row3 col10" >7.236214</td>
#       <td id="T_f9233_row3_col11" class="data row3 col11" >29.940547</td>
#       <td id="T_f9233_row3_col12" class="data row3 col12" >37.176761</td>
#     </tr>
#     <tr>
#       <th id="T_f9233_level0_row4" class="row_heading level0 row4" >5</th>
#       <td id="T_f9233_row4_col0" class="data row4 col0" >124,630</td>
#       <td id="T_f9233_row4_col1" class="data row4 col1" >39,115</td>
#       <td id="T_f9233_row4_col2" class="data row4 col2" >24,468</td>
#       <td id="T_f9233_row4_col3" class="data row4 col3" >13,220</td>
#       <td id="T_f9233_row4_col4" class="data row4 col4" >9,138</td>
#       <td id="T_f9233_row4_col5" class="data row4 col5" >100,162</td>
#       <td id="T_f9233_row4_col6" class="data row4 col6" >86,942</td>
#       <td id="T_f9233_row4_col7" class="data row4 col7" >77,804</td>
#       <td id="T_f9233_row4_col8" class="data row4 col8" >19.632512</td>
#       <td id="T_f9233_row4_col9" class="data row4 col9" >10.607398</td>
#       <td id="T_f9233_row4_col10" class="data row4 col10" >7.332103</td>
#       <td id="T_f9233_row4_col11" class="data row4 col11" >30.239910</td>
#       <td id="T_f9233_row4_col12" class="data row4 col12" >37.572013</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# fp - Highest probability in prediction vector is for an illegal move\
# tp1 - Model's number 1 choice is the correct move\
# tp2 - Model's number 2 choice is the correct move\
# tp3 - Model's number 3 choice is the correct move\
# tn1 - The correct move is not in the model's top 1 choice\
# tn2 - The correct move is not in the model's top 2 choices\
# tn3 - The correct move is not in the model's top 3 choices\
# acc1 - Model's accuracy (1st choice)\
# acc2 - Model's accuracy (2nd choice)\
# acc3 - Model's accuracy (3rd choice)\
# acctop2 - Model's accuracy (top-2)\
# acctop3 - Model's accuracy (top-3)

# %% [markdown]
# #### Accuracy (total) plot only on last state prediction

# %%
# %matplotlib inline
plot_accuracy_by_epoch(mu_1_df[["acc1", "acc2", "acc3", "acctop2", "acctop3"]],
                       loss_type = 'only last state', state_emb_type = 'linear')

# %% [markdown]
# ### Accuracy by turn only on last state prediction

# %%
stats_by_turn_df = get_stats_for_predictions_by_turn(dt_pred_folder_old, predictions_old)
for old_key in list(stats_by_turn_df.keys()):
    new_key = old_key.rpartition('_')[-1]
    stats_by_turn_df[f"epoch_{new_key}"] = stats_by_turn_df.pop(old_key)
stats_by_turn_df['epoch_1'][:40]
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████████| 5/5 [00:18<00:00,  3.74s/it]
#     total    fp  tp1  tp2  tp3   tn1   tn2   tn3       acc1       acc2  \
# 5     943   121  230  126  115   713   587   472  24.390244  13.361612
# 6    1449   223  420  233  133  1029   796   663  28.985507  16.080055
# 7    1971   358  600  277  169  1371  1094   925  30.441400  14.053780
# 8    2419   459  666  316  193  1753  1437  1244  27.532038  13.063249
# 9    2825   635  715  336  237  2110  1774  1537  25.309735  11.893805
# 10   3137   869  676  366  231  2461  2095  1864  21.549251  11.667198
# 11   3368  1134  660  361  243  2708  2347  2104  19.596200  10.718527
# 12   3532  1306  628  338  214  2904  2566  2352  17.780294   9.569649
# 13   3633  1412  550  358  230  3083  2725  2495  15.139004   9.854115
# 14   3700  1508  554  317  238  3146  2829  2591  14.972973   8.567568
# 15   3741  1777  489  297  230  3252  2955  2725  13.071371   7.939054
# 16   3760  1904  464  290  210  3296  3006  2796  12.340426   7.712766
# 17   3774  2009  413  263  192  3361  3098  2906  10.943296   6.968733
# 18   3776  2054  411  231  194  3365  3134  2940  10.884534   6.117585
# 19   3783  2094  422  257  194  3361  3104  2910  11.155168   6.793550
# 20   3779  2165  388  253  175  3391  3138  2963  10.267266   6.694893
# 21   3712  2209  331  213  194  3381  3168  2974   8.917026   5.738147
# 22   3626  2099  365  194  183  3261  3067  2884  10.066189   5.350248
# 23   3554  2140  333  211  165  3221  3010  2845   9.369724   5.936972
# 24   3469  2059  338  213  148  3131  2918  2770   9.743442   6.140098
# 25   3376  2034  374  244  148  3002  2758  2610  11.078199   7.227488
# 26   3293  1970  361  231  168  2932  2701  2533  10.962648   7.014880
# 27   3192  1848  324  224  140  2868  2644  2504  10.150376   7.017544
# 28   3096  1840  352  201  165  2744  2543  2378  11.369509   6.492248
# 29   2986  1848  329  220  173  2657  2437  2264  11.018084   7.367716
# 30   2872  1679  333  222  140  2539  2317  2177  11.594708   7.729805
# 31   2754  1663  302  229  160  2452  2223  2063  10.965868   8.315178
# 32   2648  1580  336  190  154  2312  2122  1968  12.688822   7.175227
# 33   2541  1453  345  226  157  2196  1970  1813  13.577332   8.894136
# 34   2414  1402  337  242  166  2077  1835  1669  13.960232  10.024855
# 35   2291  1351  322  232  177  1969  1737  1560  14.054998  10.126582
# 36   2173  1220  304  210  173  1869  1659  1486  13.989876   9.664059
# 37   2065  1146  306  215  154  1759  1544  1390  14.818402  10.411622
# 38   1948  1076  317  220  149  1631  1411  1262  16.273101  11.293634
# 39   1852   961  339  224  149  1513  1289  1140  18.304536  12.095032
# 40   1749   946  315  187  139  1434  1247  1108  18.010292  10.691824
# 41   1642   875  312  193  148  1330  1137   989  19.001218  11.753959
# 42   1552   848  277  185  137  1275  1090   953  17.847938  11.920103
# 43   1459   745  261  189  134  1198  1009   875  17.888965  12.954078
# 44   1372   729  273  152  117  1099   947   830  19.897959  11.078717
#
#          acc3    acctop2    acctop3
# 5   12.195122  37.751856  49.946978
# 6    9.178744  45.065562  54.244306
# 7    8.574328  44.495180  53.069508
# 8    7.978504  40.595287  48.573791
# 9    8.389381  37.203540  45.592920
# 10   7.363723  33.216449  40.580172
# 11   7.214964  30.314727  37.529691
# 12   6.058890  27.349943  33.408834
# 13   6.330856  24.993119  31.323975
# 14   6.432432  23.540541  29.972973
# 15   6.148089  21.010425  27.158514
# 16   5.585106  20.053191  25.638298
# 17   5.087440  17.912030  22.999470
# 18   5.137712  17.002119  22.139831
# 19   5.128205  17.948718  23.076923
# 20   4.630855  16.962159  21.593014
# 21   5.226293  14.655172  19.881466
# 22   5.046884  15.416437  20.463320
# 23   4.642656  15.306697  19.949353
# 24   4.266359  15.883540  20.149899
# 25   4.383886  18.305687  22.689573
# 26   5.101731  17.977528  23.079259
# 27   4.385965  17.167920  21.553885
# 28   5.329457  17.861757  23.191214
# 29   5.793704  18.385800  24.179504
# 30   4.874652  19.324513  24.199164
# 31   5.809731  19.281046  25.090777
# 32   5.815710  19.864048  25.679758
# 33   6.178670  22.471468  28.650138
# 34   6.876553  23.985087  30.861640
# 35   7.725884  24.181580  31.907464
# 36   7.961344  23.653935  31.615278
# 37   7.457627  25.230024  32.687651
# 38   7.648871  27.566735  35.215606
# 39   8.045356  30.399568  38.444924
# 40   7.947399  28.702115  36.649514
# 41   9.013398  30.755177  39.768575
# 42   8.827320  29.768041  38.595361
# 43   9.184373  30.843043  40.027416
# 44   8.527697  30.976676  39.504373

# %% [markdown]
# #### Accuracy by turn plot only on last state prediction

# %%
# %matplotlib inline
for epoch in sorted(list(stats_by_turn_df.keys())):
    plot_acc_by_turn(stats_by_turn_df[epoch][["acc1", "acc2", "acc3", "acctop2", "acctop3"]],
                     epoch = epoch, loss_type = 'only last state', state_emb_type = 'linear')

# %% [markdown]
# ### Train loss only on last state prediction

# %%
losses_dir = os.path.join(os.getcwd(),'dt_chess','training_losses_1_last')
loss_files = os.listdir(losses_dir)
loss_files
# Out:
# ['linear_Jiyarkhan_1.csv',
#  'linear_Jiyarkhan_2.csv',
#  'linear_Jiyarkhan_3.csv',
#  'linear_Jiyarkhan_4.csv',
#  'linear_Jiyarkhan_5.csv']

# %%
losses_df = get_train_losses(losses_dir, loss_files)
display(losses_df.describe())
# Out:
#            epoch_1      epoch_2      epoch_3      epoch_4      epoch_5
# count  2355.000000  2355.000000  2355.000000  2355.000000  2355.000000
# mean      5.782838     4.993579     4.625838     4.414986     4.330162
# std       0.422860     0.200347     0.153341     0.132678     0.134017
# min       4.968594     4.410265     4.124527     3.992949     3.903914
# 25%       5.481194     4.853238     4.522380     4.327068     4.240576
# 50%       5.717409     4.991352     4.625976     4.414907     4.322959
# 75%       6.015526     5.135147     4.725410     4.501634     4.422589
# max       8.469293     5.662907     5.131872     4.885103     4.775181

# %%
# %matplotlib inline
plot_train_loss(losses_df, epoch = 'epochs 1-5',
                loss_type = 'only last state', state_emb_type = 'linear')

# %% [markdown]
# ## Training loss on all state predictions (linear)

# %%
dt_pred_folder = os.path.join(os.getcwd(),'dt_chess','datasets_test_predictions')
state_emb_type = 'linear'
mu_1_all = os.listdir(dt_pred_folder)
mu_1_all = [x for x in mu_1_all if x.partition('_')[0] == state_emb_type]
mu_1_all
# Out:
# ['linear_1_400_Jiyarkhan_1.csv']

# %% [markdown]
# ### Accuracy (total)

# %%
mu_1_all_df = get_stats_for_all_predictions(dt_pred_folder, mu_1_all, unique=True)
display(mu_1_all_df.style.format(thousands=','))
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:03<00:00,  3.97s/it]
# <style type="text/css">
# </style>
# <table id="T_0c388">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0c388_level0_col0" class="col_heading level0 col0" >total</th>
#       <th id="T_0c388_level0_col1" class="col_heading level0 col1" >fp</th>
#       <th id="T_0c388_level0_col2" class="col_heading level0 col2" >tp1</th>
#       <th id="T_0c388_level0_col3" class="col_heading level0 col3" >tp2</th>
#       <th id="T_0c388_level0_col4" class="col_heading level0 col4" >tp3</th>
#       <th id="T_0c388_level0_col5" class="col_heading level0 col5" >tn1</th>
#       <th id="T_0c388_level0_col6" class="col_heading level0 col6" >tn2</th>
#       <th id="T_0c388_level0_col7" class="col_heading level0 col7" >tn3</th>
#       <th id="T_0c388_level0_col8" class="col_heading level0 col8" >acc1</th>
#       <th id="T_0c388_level0_col9" class="col_heading level0 col9" >acc2</th>
#       <th id="T_0c388_level0_col10" class="col_heading level0 col10" >acc3</th>
#       <th id="T_0c388_level0_col11" class="col_heading level0 col11" >acctop2</th>
#       <th id="T_0c388_level0_col12" class="col_heading level0 col12" >acctop3</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0c388_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_0c388_row0_col0" class="data row0 col0" >124,623</td>
#       <td id="T_0c388_row0_col1" class="data row0 col1" >35,392</td>
#       <td id="T_0c388_row0_col2" class="data row0 col2" >25,988</td>
#       <td id="T_0c388_row0_col3" class="data row0 col3" >14,178</td>
#       <td id="T_0c388_row0_col4" class="data row0 col4" >9,573</td>
#       <td id="T_0c388_row0_col5" class="data row0 col5" >98,635</td>
#       <td id="T_0c388_row0_col6" class="data row0 col6" >84,457</td>
#       <td id="T_0c388_row0_col7" class="data row0 col7" >74,884</td>
#       <td id="T_0c388_row0_col8" class="data row0 col8" >20.853294</td>
#       <td id="T_0c388_row0_col9" class="data row0 col9" >11.376712</td>
#       <td id="T_0c388_row0_col10" class="data row0 col10" >7.681568</td>
#       <td id="T_0c388_row0_col11" class="data row0 col11" >32.230006</td>
#       <td id="T_0c388_row0_col12" class="data row0 col12" >39.911573</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# fp - Highest probability in prediction vector is for an illegal move\
# tp1 - Model's number 1 choice is the correct move\
# tp2 - Model's number 2 choice is the correct move\
# tp3 - Model's number 3 choice is the correct move\
# tn1 - The correct move is not in the model's top 1 choice\
# tn2 - The correct move is not in the model's top 2 choices\
# tn3 - The correct move is not in the model's top 3 choices\
# acc1 - Model's accuracy (1st choice)\
# acc2 - Model's accuracy (2nd choice)\
# acc3 - Model's accuracy (3rd choice)\
# acctop2 - Model's accuracy (top-2)\
# acctop3 - Model's accuracy (top-3)

# %% [markdown]
# #### Accuracy (total) on all state predictions (linear)

# %%
# %matplotlib inline
### There are no multiple epochs to plot ##
# plot_accuracy_by_epoch(mu_1_all_df[["acc1", "acc2", "acc3", "acctop2", "acctop3"]],
#                        loss_type = 'all states', state_emb_type = state_emb_type)

# %% [markdown]
# ### Accuracy by turn on all state predictions (linear)

# %%
stats_by_turn_df = get_stats_for_predictions_by_turn(dt_pred_folder, mu_1_all)
for old_key in list(stats_by_turn_df.keys()):
    new_key = old_key.rpartition('_')[-1]
    stats_by_turn_df[f"epoch_{new_key}"] = stats_by_turn_df.pop(old_key)
stats_by_turn_df['epoch_1'][:40]
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:03<00:00,  3.74s/it]
#     total    fp   tp1  tp2  tp3   tn1   tn2   tn3       acc1       acc2  \
# 5     944    44   361  165  117   583   418   301  38.241525  17.478814
# 6    1448    89   594  283  138   854   571   433  41.022099  19.544199
# 7    1971   125   800  340  216  1171   831   615  40.588534  17.250127
# 8    2418   178   944  423  244  1474  1051   807  39.040529  17.493797
# 9    2822   248  1081  461  267  1741  1280  1013  38.306166  16.335932
# 10   3136   359  1053  490  312  2083  1593  1281  33.577806  15.625000
# 11   3367   429  1055  508  300  2312  1804  1504  31.333531  15.087615
# 12   3532   506  1061  488  300  2471  1983  1683  30.039638  13.816535
# 13   3630   591   997  464  290  2633  2169  1879  27.465565  12.782369
# 14   3700   634   922  425  322  2778  2353  2031  24.918919  11.486486
# 15   3741   707   861  406  304  2880  2474  2170  23.015237  10.852713
# 16   3761   707   781  438  282  2980  2542  2260  20.765754  11.645839
# 17   3773   821   739  379  232  3034  2655  2423  19.586536  10.045057
# 18   3776   801   699  338  237  3077  2739  2502  18.511653   8.951271
# 19   3783   907   676  397  226  3107  2710  2484  17.869416  10.494317
# 20   3779  1048   580  338  248  3199  2861  2613  15.347976   8.944165
# 21   3712  1049   571  306  232  3141  2835  2603  15.382543   8.243534
# 22   3626  1084   522  283  235  3104  2821  2586  14.396029   7.804744
# 23   3554  1099   493  296  189  3061  2765  2576  13.871694   8.328644
# 24   3469  1139   499  308  199  2970  2662  2463  14.384549   8.878639
# 25   3376  1162   499  295  206  2877  2582  2376  14.780806   8.738152
# 26   3293  1130   488  267  205  2805  2538  2333  14.819314   8.108108
# 27   3192  1111   449  241  187  2743  2502  2315  14.066416   7.550125
# 28   3096  1159   449  253  215  2647  2394  2179  14.502584   8.171835
# 29   2986  1157   394  261  183  2592  2331  2148  13.194910   8.740790
# 30   2872  1082   383  241  176  2489  2248  2072  13.335655   8.391365
# 31   2754  1035   382  249  173  2372  2123  1950  13.870733   9.041394
# 32   2648  1017   394  238  155  2254  2016  1861  14.879154   8.987915
# 33   2541   961   398  255  162  2143  1888  1726  15.663125  10.035419
# 34   2414   979   376  244  167  2038  1794  1627  15.575808  10.107705
# 35   2291   917   408  212  171  1883  1671  1500  17.808817   9.253601
# 36   2173   852   361  223  160  1812  1589  1429  16.612977  10.262310
# 37   2065   807   361  237  143  1704  1467  1324  17.481840  11.476998
# 38   1948   716   349  226  145  1599  1373  1228  17.915811  11.601643
# 39   1852   681   354  211  162  1498  1287  1125  19.114471  11.393089
# 40   1749   677   333  204  143  1416  1212  1069  19.039451  11.663808
# 41   1642   665   339  193  137  1303  1110   973  20.645554  11.753959
# 42   1552   614   296  179  147  1256  1077   930  19.072165  11.533505
# 43   1459   556   270  180  134  1189  1009   875  18.505826  12.337217
# 44   1372   547   268  159  124  1104   945   821  19.533528  11.588921
#
#          acc3    acctop2    acctop3
# 5   12.394068  55.720339  68.114407
# 6    9.530387  60.566298  70.096685
# 7   10.958904  57.838661  68.797565
# 8   10.090984  56.534326  66.625310
# 9    9.461375  54.642098  64.103473
# 10   9.948980  49.202806  59.151786
# 11   8.910009  46.421146  55.331155
# 12   8.493771  43.856172  52.349943
# 13   7.988981  40.247934  48.236915
# 14   8.702703  36.405405  45.108108
# 15   8.126169  33.867950  41.994119
# 16   7.498006  32.411593  39.909599
# 17   6.148953  29.631593  35.780546
# 18   6.276483  27.462924  33.739407
# 19   5.974095  28.363732  34.337827
# 20   6.562583  24.292141  30.854723
# 21   6.250000  23.626078  29.876078
# 22   6.480971  22.200772  28.681743
# 23   5.317952  22.200338  27.518289
# 24   5.736523  23.263188  28.999712
# 25   6.101896  23.518957  29.620853
# 26   6.225326  22.927422  29.152748
# 27   5.858396  21.616541  27.474937
# 28   6.944444  22.674419  29.618863
# 29   6.128600  21.935700  28.064300
# 30   6.128134  21.727019  27.855153
# 31   6.281772  22.912128  29.193900
# 32   5.853474  23.867069  29.720544
# 33   6.375443  25.698544  32.073987
# 34   6.917978  25.683513  32.601491
# 35   7.463990  27.062418  34.526408
# 36   7.363092  26.875288  34.238380
# 37   6.924939  28.958838  35.883777
# 38   7.443532  29.517454  36.960986
# 39   8.747300  30.507559  39.254860
# 40   8.176101  30.703259  38.879360
# 41   8.343484  32.399513  40.742996
# 42   9.471649  30.605670  40.077320
# 43   9.184373  30.843043  40.027416
# 44   9.037901  31.122449  40.160350

# %% [markdown]
# #### Accuracy by turn plot on all state predictions (linear)

# %%
# %matplotlib inline
for epoch in sorted(list(stats_by_turn_df.keys())):
    plot_acc_by_turn(stats_by_turn_df[epoch][["acc1", "acc2", "acc3", "acctop2", "acctop3"]],
                     epoch = epoch, loss_type = 'all states', state_emb_type = state_emb_type)

# %% [markdown]
# ### Train loss on all state predictions (linear)

# %%
losses_all_dir = os.path.join(os.getcwd(),'dt_chess','training_losses')
loss_all_files = os.listdir(losses_all_dir)
loss_all_files = [x for x in loss_all_files if x.partition('_')[0] == state_emb_type]
# print(loss_all_files)
losses_df = get_train_losses(losses_all_dir, loss_all_files)
display(losses_df.describe().T)
# Out:
#           count      mean       std       min       25%       50%       75%  \
# epoch_1  2355.0  4.349157  1.041613  2.899043  3.459117  4.044686  5.189452
# epoch_2  2355.0  2.686371  0.221668  2.202177  2.503418  2.666051  2.856728
# epoch_3  2355.0  2.176302  0.107258  1.874041  2.094524  2.174700  2.253011
#
#               max
# epoch_1  8.473842
# epoch_2  3.280200
# epoch_3  2.512263

# %%
# %matplotlib inline
plot_train_loss(losses_df, epoch = losses_df.columns[0],
                loss_type = 'all states', state_emb_type = state_emb_type)

# %% [markdown]
# ## Training loss on all state predictions (convolutional)

# %%
state_emb_type = 'convolutional'
mu_1_all = os.listdir(dt_pred_folder)
mu_1_all = [x for x in mu_1_all if x.partition('_')[0] == state_emb_type]
mu_1_all
# Out:
# ['convolutional_1_400_Jiyarkhan_1.csv',
#  'convolutional_1_400_Jiyarkhan_2.csv',
#  'convolutional_1_400_Jiyarkhan_3.csv']

# %% [markdown]
# ### Accuracy (total) on all state predictions (convolutional)

# %%
mu_1_all_df = get_stats_for_all_predictions(dt_pred_folder, mu_1_all, unique=True)
display(mu_1_all_df.style.format(thousands=','))
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████████| 3/3 [00:21<00:00,  7.19s/it]
# <style type="text/css">
# </style>
# <table id="T_9e316">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9e316_level0_col0" class="col_heading level0 col0" >total</th>
#       <th id="T_9e316_level0_col1" class="col_heading level0 col1" >fp</th>
#       <th id="T_9e316_level0_col2" class="col_heading level0 col2" >tp1</th>
#       <th id="T_9e316_level0_col3" class="col_heading level0 col3" >tp2</th>
#       <th id="T_9e316_level0_col4" class="col_heading level0 col4" >tp3</th>
#       <th id="T_9e316_level0_col5" class="col_heading level0 col5" >tn1</th>
#       <th id="T_9e316_level0_col6" class="col_heading level0 col6" >tn2</th>
#       <th id="T_9e316_level0_col7" class="col_heading level0 col7" >tn3</th>
#       <th id="T_9e316_level0_col8" class="col_heading level0 col8" >acc1</th>
#       <th id="T_9e316_level0_col9" class="col_heading level0 col9" >acc2</th>
#       <th id="T_9e316_level0_col10" class="col_heading level0 col10" >acc3</th>
#       <th id="T_9e316_level0_col11" class="col_heading level0 col11" >acctop2</th>
#       <th id="T_9e316_level0_col12" class="col_heading level0 col12" >acctop3</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9e316_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_9e316_row0_col0" class="data row0 col0" >124,601</td>
#       <td id="T_9e316_row0_col1" class="data row0 col1" >19,104</td>
#       <td id="T_9e316_row0_col2" class="data row0 col2" >29,499</td>
#       <td id="T_9e316_row0_col3" class="data row0 col3" >15,479</td>
#       <td id="T_9e316_row0_col4" class="data row0 col4" >10,142</td>
#       <td id="T_9e316_row0_col5" class="data row0 col5" >95,102</td>
#       <td id="T_9e316_row0_col6" class="data row0 col6" >79,623</td>
#       <td id="T_9e316_row0_col7" class="data row0 col7" >69,481</td>
#       <td id="T_9e316_row0_col8" class="data row0 col8" >23.674770</td>
#       <td id="T_9e316_row0_col9" class="data row0 col9" >12.422854</td>
#       <td id="T_9e316_row0_col10" class="data row0 col10" >8.139582</td>
#       <td id="T_9e316_row0_col11" class="data row0 col11" >36.097624</td>
#       <td id="T_9e316_row0_col12" class="data row0 col12" >44.237205</td>
#     </tr>
#     <tr>
#       <th id="T_9e316_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_9e316_row1_col0" class="data row1 col0" >124,616</td>
#       <td id="T_9e316_row1_col1" class="data row1 col1" >13,838</td>
#       <td id="T_9e316_row1_col2" class="data row1 col2" >35,138</td>
#       <td id="T_9e316_row1_col3" class="data row1 col3" >17,213</td>
#       <td id="T_9e316_row1_col4" class="data row1 col4" >10,646</td>
#       <td id="T_9e316_row1_col5" class="data row1 col5" >89,478</td>
#       <td id="T_9e316_row1_col6" class="data row1 col6" >72,265</td>
#       <td id="T_9e316_row1_col7" class="data row1 col7" >61,619</td>
#       <td id="T_9e316_row1_col8" class="data row1 col8" >28.197021</td>
#       <td id="T_9e316_row1_col9" class="data row1 col9" >13.812833</td>
#       <td id="T_9e316_row1_col10" class="data row1 col10" >8.543044</td>
#       <td id="T_9e316_row1_col11" class="data row1 col11" >42.009854</td>
#       <td id="T_9e316_row1_col12" class="data row1 col12" >50.552899</td>
#     </tr>
#     <tr>
#       <th id="T_9e316_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_9e316_row2_col0" class="data row2 col0" >124,602</td>
#       <td id="T_9e316_row2_col1" class="data row2 col1" >11,629</td>
#       <td id="T_9e316_row2_col2" class="data row2 col2" >37,633</td>
#       <td id="T_9e316_row2_col3" class="data row2 col3" >17,583</td>
#       <td id="T_9e316_row2_col4" class="data row2 col4" >10,652</td>
#       <td id="T_9e316_row2_col5" class="data row2 col5" >86,969</td>
#       <td id="T_9e316_row2_col6" class="data row2 col6" >69,386</td>
#       <td id="T_9e316_row2_col7" class="data row2 col7" >58,734</td>
#       <td id="T_9e316_row2_col8" class="data row2 col8" >30.202565</td>
#       <td id="T_9e316_row2_col9" class="data row2 col9" >14.111330</td>
#       <td id="T_9e316_row2_col10" class="data row2 col10" >8.548819</td>
#       <td id="T_9e316_row2_col11" class="data row2 col11" >44.313895</td>
#       <td id="T_9e316_row2_col12" class="data row2 col12" >52.862715</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# fp - Highest probability in prediction vector is for an illegal move\
# tp1 - Model's number 1 choice is the correct move\
# tp2 - Model's number 2 choice is the correct move\
# tp3 - Model's number 3 choice is the correct move\
# tn1 - The correct move is not in the model's top 1 choice\
# tn2 - The correct move is not in the model's top 2 choices\
# tn3 - The correct move is not in the model's top 3 choices\
# acc1 - Model's accuracy (1st choice)\
# acc2 - Model's accuracy (2nd choice)\
# acc3 - Model's accuracy (3rd choice)\
# acctop2 - Model's accuracy (top-2)\
# acctop3 - Model's accuracy (top-3)

# %% [markdown]
# #### Accuracy (total) on all state predictions (convolutional)

# %%
# %matplotlib inline
### There are no multiple epochs to plot ##
plot_accuracy_by_epoch(mu_1_all_df[["acc1", "acc2", "acc3", "acctop2", "acctop3"]],
                       loss_type = 'all states', state_emb_type = state_emb_type)

# %% [markdown]
# ### Accuracy by turn on all state predictions (convolutional)

# %%
stats_by_turn_df = get_stats_for_predictions_by_turn(dt_pred_folder, mu_1_all)
for old_key in list(stats_by_turn_df.keys()):
    new_key = old_key.rpartition('_')[-1]
    stats_by_turn_df[f"epoch_{new_key}"] = stats_by_turn_df.pop(old_key)
stats_by_turn_df['epoch_1'][:40]
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████████| 3/3 [00:11<00:00,  3.89s/it]
#     total   fp   tp1  tp2  tp3   tn1   tn2   tn3       acc1       acc2  \
# 5     942   28   349  209   91   593   384   293  37.048832  22.186837
# 6    1447   49   633  254  148   814   560   412  43.745681  17.553559
# 7    1966   77   814  380  209  1152   772   563  41.403866  19.328586
# 8    2417  102   978  439  255  1439  1000   745  40.463384  18.163012
# 9    2820  143  1175  456  267  1645  1189   922  41.666667  16.170213
# 10   3132  182  1186  456  320  1946  1490  1170  37.867178  14.559387
# 11   3362  210  1216  525  298  2146  1621  1323  36.168947  15.615705
# 12   3529  192  1240  523  313  2289  1766  1453  35.137433  14.820062
# 13   3631  217  1149  544  318  2482  1938  1620  31.644175  14.982099
# 14   3700  234  1073  517  317  2627  2110  1793  29.000000  13.972973
# 15   3741  293  1055  503  307  2686  2183  1876  28.201016  13.445603
# 16   3760  285   959  496  297  2801  2305  2008  25.505319  13.191489
# 17   3774  337   914  426  303  2860  2434  2131  24.218336  11.287758
# 18   3776  336   850  436  292  2926  2490  2198  22.510593  11.546610
# 19   3783  398   851  434  260  2932  2498  2238  22.495374  11.472376
# 20   3779  426   751  380  258  3028  2648  2390  19.872982  10.055570
# 21   3712  417   742  369  251  2970  2601  2350  19.989224   9.940733
# 22   3626  420   656  422  248  2970  2548  2300  18.091561  11.638169
# 23   3554  431   636  352  232  2918  2566  2334  17.895329   9.904333
# 24   3469  465   631  317  234  2838  2521  2287  18.189680   9.138080
# 25   3376  503   624  308  243  2752  2444  2201  18.483412   9.123223
# 26   3293  533   600  312  211  2693  2381  2170  18.220468   9.474643
# 27   3192  501   521  317  205  2671  2354  2149  16.322055   9.931078
# 28   3096  565   549  297  202  2547  2250  2048  17.732558   9.593023
# 29   2986  557   445  271  217  2541  2270  2053  14.902880   9.075687
# 30   2872  564   449  290  184  2423  2133  1949  15.633705  10.097493
# 31   2754  522   465  266  218  2289  2023  1805  16.884532   9.658678
# 32   2648  525   463  245  182  2185  1940  1758  17.484894   9.252266
# 33   2541  549   430  254  188  2111  1857  1669  16.922471   9.996065
# 34   2414  519   421  264  190  1993  1729  1539  17.439934  10.936205
# 35   2291  519   412  267  156  1879  1612  1456  17.983413  11.654299
# 36   2173  524   412  258  163  1761  1503  1340  18.959963  11.872987
# 37   2065  484   387  246  140  1678  1432  1292  18.740920  11.912833
# 38   1948  458   337  234  172  1611  1377  1205  17.299795  12.012320
# 39   1852  440   352  209  160  1500  1291  1131  19.006479  11.285097
# 40   1749  425   344  215  163  1405  1190  1027  19.668382  12.292739
# 41   1642  462   337  193  117  1305  1112   995  20.523752  11.753959
# 42   1552  429   302  189  139  1250  1061   922  19.458763  12.177835
# 43   1459  399   273  194  134  1186   992   858  18.711446  13.296779
# 44   1372  356   297  164  110  1075   911   801  21.647230  11.953353
#
#          acc3    acctop2    acctop3
# 5    9.660297  59.235669  68.895966
# 6   10.228058  61.299240  71.527298
# 7   10.630722  60.732452  71.363174
# 8   10.550269  58.626396  69.176665
# 9    9.468085  57.836879  67.304965
# 10  10.217114  52.426564  62.643678
# 11   8.863772  51.784652  60.648424
# 12   8.869368  49.957495  58.826863
# 13   8.757918  46.626274  55.384192
# 14   8.567568  42.972973  51.540541
# 15   8.206362  41.646619  49.852980
# 16   7.898936  38.696809  46.595745
# 17   8.028617  35.506094  43.534711
# 18   7.733051  34.057203  41.790254
# 19   6.872852  33.967750  40.840603
# 20   6.827203  29.928553  36.755755
# 21   6.761853  29.929957  36.691810
# 22   6.839493  29.729730  36.569222
# 23   6.527856  27.799662  34.327518
# 24   6.745460  27.327760  34.073220
# 25   7.197867  27.606635  34.804502
# 26   6.407531  27.695111  34.102642
# 27   6.422306  26.253133  32.675439
# 28   6.524548  27.325581  33.850129
# 29   7.267247  23.978567  31.245814
# 30   6.406685  25.731198  32.137883
# 31   7.915759  26.543210  34.458969
# 32   6.873112  26.737160  33.610272
# 33   7.398662  26.918536  34.317198
# 34   7.870754  28.376139  36.246893
# 35   6.809254  29.637713  36.446966
# 36   7.501150  30.832950  38.334100
# 37   6.779661  30.653753  37.433414
# 38   8.829569  29.312115  38.141684
# 39   8.639309  30.291577  38.930886
# 40   9.319611  31.961121  41.280732
# 41   7.125457  32.277710  39.403167
# 42   8.956186  31.636598  40.592784
# 43   9.184373  32.008225  41.192598
# 44   8.017493  33.600583  41.618076

# %% [markdown]
# #### Accuracy by turn plot on all state predictions (convolutional)

# %%
# %matplotlib inline
for epoch in sorted(list(stats_by_turn_df.keys())):
    plot_acc_by_turn(stats_by_turn_df[epoch][["acc1", "acc2", "acc3", "acctop2", "acctop3"]],
                     epoch = epoch, loss_type = 'all states', state_emb_type = state_emb_type)

# %% [markdown]
# ### Train loss on all state predictions (convolutional)

# %%
loss_all_files = os.listdir(losses_all_dir)
loss_all_files = [x for x in loss_all_files if x.partition('_')[0] == state_emb_type]
# print(loss_all_files)
losses_df = get_train_losses(losses_all_dir, loss_all_files)
display(losses_df.describe().T)
# Out:
#           count      mean       std       min       25%       50%       75%  \
# epoch_1  2355.0  4.349157  1.041613  2.899043  3.459117  4.044686  5.189452
# epoch_2  2355.0  2.686371  0.221668  2.202177  2.503418  2.666051  2.856728
# epoch_3  2355.0  2.176302  0.107258  1.874041  2.094524  2.174700  2.253011
#
#               max
# epoch_1  8.473842
# epoch_2  3.280200
# epoch_3  2.512263

# %%
# %matplotlib inline
plot_train_loss(losses_df, epoch = losses_df.columns[0],
                loss_type = 'all states', state_emb_type = state_emb_type)
